# %%
# !mkdir ./features
# !mkdir ./features/0x014c
# !mkdir ./features/0x01c4
# !mkdir ./features/0x0166
# !mkdir ./features/0x0184
# !mkdir ./features/0x8664
# !mkdir ./features/0xaa64
# !mkdir ./features/elsePE
# !mkdir ./features/NonPE
# !mkdir ./files
# !mkdir ./files/2020_sample
# !mkdir ./files/2020_sample/trainSet
# Out:
# mkdir: cannot create directory ‘./features’: File exists
# mkdir: cannot create directory ‘./features/0x014c’: File exists
# mkdir: cannot create directory ‘./files’: File exists
